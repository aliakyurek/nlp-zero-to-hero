# %% [markdown]
# <a href="https://colab.research.google.com/github/aliakyurek/nlp-zero-to-hero/blob/main/5_Language_translation_with_GRU_and_Bahdanau.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Delete everything in current dir to be able to clone directly to current dir.
# !rm -rf *
# !rm -rf .*

# %%
# !git clone https://github.com/aliakyurek/nlp-zero-to-hero.git .

# %%
# !pip install -q pytorch-lightning datasets spacy

# %%
# !python -m spacy download de_core_news_sm &> /dev/null

# %%
# %load 5\main.py

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
